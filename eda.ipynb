# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('ABR exported files/B2_1283_baseline.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Columns: 293 entries, SGI to
# dtypes: float64(281), int64(9), object(3)
# memory usage: 171.8+ KB

# %%
data.describe()
# Out:
#              SGI    Rec No.  Gain    No. Avgs  No. Arts          Time  Chan  \
# count  75.000000  75.000000  75.0   75.000000      75.0  7.500000e+01  75.0
# mean   38.000000  37.000000  20.0  509.893333       0.0  1.696883e+09   1.0
# std    21.794495  21.794495   0.0   18.244269       0.0  5.388425e+02   0.0
# min     1.000000   0.000000  20.0  354.000000       0.0  1.696882e+09   1.0
# 25%    19.500000  18.500000  20.0  512.000000       0.0  1.696883e+09   1.0
# 50%    38.000000  37.000000  20.0  512.000000       0.0  1.696883e+09   1.0
# 75%    56.500000  55.500000  20.0  512.000000       0.0  1.696884e+09   1.0
# max    75.000000  74.000000  20.0  512.000000       0.0  1.696884e+09   1.0
#
#        Sub. ID  Sub. Memo  Unnamed: 11  ...        234        235        236  \
# count     75.0        0.0          0.0  ...  75.000000  75.000000  75.000000
# mean    1283.0        NaN          NaN  ...  -0.000507  -0.000627  -0.000680
# ...

# %%
data.head()
# Out:
#    SGI  Rec No.  Gain  No. Avgs  No. Arts        Time  Chan  Sub. ID  \
# 0    1        0    20       354         0  1696882342     1     1283
# 1    2        1    20       512         0  1696882367     1     1283
# 2    3        2    20       512         0  1696882392     1     1283
# 3    4        3    20       512         0  1696882416     1     1283
# 4    5        4    20       512         0  1696882441     1     1283
#
#   Sub. Ref-1 Sub. Ref-2  ...    235    236    237    238    239    240    241  \
# 0         B2       base  ...  0.006  0.004  0.002  0.000 -0.001 -0.003 -0.004
# 1         B2       base  ...  0.000  0.001  0.003  0.003  0.004  0.004  0.003
# 2         B2       base  ...  0.002  0.004  0.005  0.006  0.006  0.005  0.005
# 3         B2       base  ...  0.006  0.005  0.004  0.003  0.003  0.002  0.001
# 4         B2       base  ...  0.005  0.006  0.006  0.006  0.006  0.005  0.004
#
#      242    243
# 0 -0.007 -0.009
# 1  0.002  0.001
# 2  0.005  0.004
# ...

# %%
data.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
khz16 = data[data['Freq(Hz)'] == 16000]

# %%
best = khz16[khz16['Level(dB)'] == 90]

# %%
best
# Out:
#     SGI  Rec No.  Gain  No. Avgs  No. Arts        Time  Chan  Sub. ID  \
# 30   31       30    20       512         0  1696883084     1     1283
#
#    Sub. Ref-1 Sub. Ref-2  ...    235    236    237    238    239    240  \
# 30         B2       base  ... -0.009 -0.009 -0.008 -0.007 -0.006 -0.006
#
#       241    242    243
# 30 -0.005 -0.004 -0.003
#
# [1 rows x 293 columns]

# %%
X = best
