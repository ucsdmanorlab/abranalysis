# %%
import pandas as pd
import os
import glob
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import find_peaks

# %% [markdown]
# # 1. Plotting Waves

# %%
#read each csv file in current_directory and store it in dataframes

current_directory = os.getcwd()
csv_files = glob.glob(os.path.join(current_directory, 'ABR_exported_files/*.csv'))

dataframes = {}
for file in csv_files:
    filename = os.path.splitext(os.path.basename(file))[0]
    if pd.read_csv(file).shape[1] > 1:
        dataframes[filename] = pd.read_csv(file)
    else:
        dataframes[filename] = pd.read_csv(file, skiprows=2)

# %%
pd.read_csv('ABR_exported_files/A1_1294_24h PSI.csv').shape[1]
# Out:
# 1

# %%
for filename, df in dataframes.items():
    khz = df[df['Freq(Hz)'] == 8000]
    dbkhz = khz[khz['Level(dB)'] == 90]
    index = dbkhz.index.values[0]
    final = df.iloc[index,48:]
    final = pd.to_numeric(final, errors='coerce')
    
    plt.figure()  
    final.plot()
    plt.title(f'sheet: {filename}') 
    plt.show()

# %% [markdown]
# # 2. Identifying Peaks

# %%
for filename, df in dataframes.items():
    khz = df[df['Freq(Hz)'] == 16000]
    dbkhz = khz[khz['Level(dB)'] == 70]
    index = dbkhz.index.values[0]
    final = df.iloc[index,48:]
    final = pd.to_numeric(final, errors='coerce')

    #find highest peaks separated by atleast n data points
    n = 20
    peaks, _ = find_peaks(final, distance=n)
    highest_peaks = peaks[np.argsort(final[peaks])[-5:]]
    
    plt.figure()
    plt.plot(final)
    plt.plot(highest_peaks, final[highest_peaks], "x")
    plt.title(f'sheet: {filename}')
    plt.show()
# Out:
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/1978282247.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   highest_peaks = peaks[np.argsort(final[peaks])[-5:]]
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/1978282247.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.plot(highest_peaks, final[highest_peaks], "x")
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/1978282247.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   highest_peaks = peaks[np.argsort(final[peaks])[-5:]]
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/1978282247.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.plot(highest_peaks, final[highest_peaks], "x")
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/1978282247.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   highest_peaks = peaks[np.argsort(final[peaks])[-5:]]
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/1978282247.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.plot(highest_peaks, final[highest_peaks], "x")
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/1978282247.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   highest_peaks = peaks[np.argsort(final[peaks])[-5:]]
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/1978282247.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.plot(highest_peaks, final[highest_peaks], "x")
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/1978282247.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   highest_peaks = peaks[np.argsort(final[peaks])[-5:]]
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/1978282247.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.plot(highest_peaks, final[highest_peaks], "x")
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/1978282247.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   highest_peaks = peaks[np.argsort(final[peaks])[-5:]]
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/1978282247.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.plot(highest_peaks, final[highest_peaks], "x")
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/1978282247.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   highest_peaks = peaks[np.argsort(final[peaks])[-5:]]
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/1978282247.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.plot(highest_peaks, final[highest_peaks], "x")
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/1978282247.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   highest_peaks = peaks[np.argsort(final[peaks])[-5:]]
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/1978282247.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.plot(highest_peaks, final[highest_peaks], "x")
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/1978282247.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   highest_peaks = peaks[np.argsort(final[peaks])[-5:]]
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/1978282247.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.plot(highest_peaks, final[highest_peaks], "x")
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/1978282247.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   highest_peaks = peaks[np.argsort(final[peaks])[-5:]]
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/1978282247.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.plot(highest_peaks, final[highest_peaks], "x")

# %%
def plotting_waves(dataframes=dataframes, freq=16000, db=90):
    for filename, df in dataframes.items():
        khz = df[df['Freq(Hz)'] == freq]
        dbkhz = khz[khz['Level(dB)'] == db]
        index = dbkhz.index.values[0]
        final = df.iloc[index,48:]
        final = pd.to_numeric(final, errors='coerce')

        #find highest peaks separated by atleast n data points
        n = 20
        peaks, _ = find_peaks(final, distance=n)
        highest_peaks = peaks[np.argsort(final[peaks])[-5:]]
    
        plt.figure()
        plt.plot(final)
        plt.plot(highest_peaks, final[highest_peaks], "x")
        plt.title(f'sheet: {filename}')
        plt.show()

# %%
plotting_waves(freq=16000, db=50)
# Out:
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/752652044.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   highest_peaks = peaks[np.argsort(final[peaks])[-5:]]
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/752652044.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.plot(highest_peaks, final[highest_peaks], "x")
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/752652044.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   highest_peaks = peaks[np.argsort(final[peaks])[-5:]]
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/752652044.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.plot(highest_peaks, final[highest_peaks], "x")
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/752652044.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   highest_peaks = peaks[np.argsort(final[peaks])[-5:]]
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/752652044.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.plot(highest_peaks, final[highest_peaks], "x")
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/752652044.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   highest_peaks = peaks[np.argsort(final[peaks])[-5:]]
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/752652044.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.plot(highest_peaks, final[highest_peaks], "x")
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/752652044.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   highest_peaks = peaks[np.argsort(final[peaks])[-5:]]
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/752652044.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.plot(highest_peaks, final[highest_peaks], "x")
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/752652044.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   highest_peaks = peaks[np.argsort(final[peaks])[-5:]]
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/752652044.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.plot(highest_peaks, final[highest_peaks], "x")
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/752652044.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   highest_peaks = peaks[np.argsort(final[peaks])[-5:]]
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/752652044.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.plot(highest_peaks, final[highest_peaks], "x")
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/752652044.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   highest_peaks = peaks[np.argsort(final[peaks])[-5:]]
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/752652044.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.plot(highest_peaks, final[highest_peaks], "x")
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/752652044.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   highest_peaks = peaks[np.argsort(final[peaks])[-5:]]
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/752652044.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.plot(highest_peaks, final[highest_peaks], "x")
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/752652044.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   highest_peaks = peaks[np.argsort(final[peaks])[-5:]]
# /var/folders/bp/pzmg_4bx0kxc4_jr5p1npj1h0000gn/T/ipykernel_57503/752652044.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.plot(highest_peaks, final[highest_peaks], "x")

# %%
data = pd.read_csv('ABR_exported_files/A1_1293_24h PSI.csv', skiprows=2)
khz = data[data['Freq(Hz)'] == 16000]
dbkhz = khz[khz['Level(dB)'] == 90]
index = dbkhz.index.values[0]
final = data.iloc[index,48:]
final = pd.to_numeric(final, errors='coerce')

# %%
for filename, df in dataframes.items():
    khz = df[df['Freq(Hz)'] == 8000]
    dbkhz = khz[khz['Level(dB)'] == 90]
    index = dbkhz.index.values[0]
    final = df.iloc[index,48:]
    final = pd.to_numeric(final, errors='coerce')
    x = final.index.values[:-1].astype(int)
    dy_dx = np.gradient(final[:-1], final.index.values[:-1].astype(int))

    # Calculate the second derivative
    d2y_dx2 = np.gradient(dy_dx, final.index.values[:-1].astype(int))

    # Plot the original data and the second derivative
    plt.figure(figsize=(10, 6))

    plt.subplot(2, 1, 1)
    plt.plot(x, final[:-1], label='Original Data')
    plt.title(f'sheet: {filename}')

    #plt.subplot(2, 1, 2)
    #plt.plot(x, dy_dx, label='First Derivative')
    #plt.title('First Derivative')

    plt.subplot(2, 1, 2)
    plt.plot(x, d2y_dx2, label='Second Derivative')
    plt.title('Second Derivative')
